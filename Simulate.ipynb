# %%
from simulator import *
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Full GUI

# %%
show(start_jupyter)
# Out:
# <script id="1003">
#   (function() {
#     const xhr = new XMLHttpRequest()
#     xhr.responseType = 'blob';
#     xhr.open('GET', "http://localhost:38219/autoload.js?bokeh-autoload-element=1003&bokeh-absolute-url=http://localhost:38219&resources=none", true);
#
#     xhr.onload = function (event) {
#       const script = document.createElement('script');
#       const src = URL.createObjectURL(event.target.response);
#       script.src = src;
#       document.body.appendChild(script);
#     };
#     xhr.send();
#   })();
# </script>
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1035', ...)
# Run clicked, simulating...
# Eqn_params: [0.01, 1.0, 0.0, 0.0, 'POWER']
# Simulating... t = 1.0/1.0
# Simulation Completed

# %% [markdown]
# # Manually Simulating

# %%
N,L,dt,x_axis,R_mass,M,rho_1,rho_0,rho_J,phi_0_array,dot_0_array,y0 = initialize()
phi1,dot1,t1 = simulate(C0=1e-2,c_th=1,D0=0,d_th=0,
                        ti=0,tf=1,dt=dt,
                        save_interval=0.01,
                        method='RK4',model='POWER')
# Out:
# Simulating... t = 1.0/1

# %%
ax,_ = plot(x_axis,phi1,t1,20,yscale='linear',return_axes=True)
ax.plot(x_axis,rho_J/np.max(rho_J)*np.max(phi1[-1]),lw=4,linestyle='--',c='orange',zorder=5,label='Relative Density')
ax.legend(frameon=False)
